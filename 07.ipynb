# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from PIL import Image

# %%
my_path = 'C:/Users/QUOC DAT/Downloads/computer-vision-main/computer-vision-main/images/1.jpg'

im = Image.open(my_path)

plt.imshow(im)

# %%
x = [1, 2, 3, 4, 5]
y = [10, 16, 20, 30, 25]
plt.plot(x, y)
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [10, 16, 20, 30, 25]
plt.plot(x, y, color='red')
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [10, 16, 20, 30, 25]
plt.plot(x, y, color='red') 
plt.title('Ví dụ về biểu đồ') 
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [10, 16, 20, 30, 25]

plt.plot(x, y, color='red')  
plt.title('Biểu đồ ví dụ với màu đỏ')  

plt.axis('off')  
plt.show()

# %%
im = Image.open(my_path)
x = [100, 100, 400, 400]
y = [200, 300, 200, 300]

plt.imshow(im) 
plt.plot(x,y, 'bo--') 
plt.show()
